# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using Selenium for this, *not* BeautifulSoup and requests.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.tdlr.texas.gov/cimsfo/fosearch.asp')

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for cosmetologist violations for people with the last name **Nguyen**.

# %%
dropdown = Select(driver.find_element_by_name("pht_status"))
dropdown.select_by_visible_text('Cosmetologists')

# %%
last_name = driver.find_element_by_name('pht_lnm')

# %%
last_name.send_keys('Nguyen')

# %%
button = driver.find_element_by_name('B1')
driver.execute_script("arguments[0].scrollIntoView(true)", button)
button.click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this.

# %% [markdown]
# ### Loop through each result and print the entire row
#
# Okay wait, that's a heck of a lot. Use `[:10]` to only do the first ten (`listname[:10]` gives you the first ten).

# %%
rows = driver.find_elements_by_tag_name('tr')
for row in rows[:10]:
    print(row.text)
# Out:
# Name and Location Order Basis for Order
# NGUYEN, TOAN HUU
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78217
#
#
# License #(s): 780948, 1706491, 1699123
#
# Complaint # COS20180004289 Date: 5/30/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, HANH CONG
# City: EL PASO
# County: EL PASO
# Zip Code: 79934
#
#
# License #: 737708
#
# Complaint # COS20180006594 Date: 5/30/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# NGUYEN, KHIEM VAN
# City: LONGVIEW
# County: GREGG
# Zip Code: 75604
#
#
# License #: 731665
#
# Complaint # COS20180000257 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,250. Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# NGUYEN, DIEP THI NGOC
# City: HOUSTON
# County: HARRIS
# Zip Code: 77014
#
#
# License #(s): 1347649, 760528
#
# Complaint # COS20180004915 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $500. Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client.
# NGUYEN, LAN T-THUY
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78255
#
# NGUYEN, SAMLOI
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78255
#
#
# License #: 767339
#
# Complaint # COS20180009255 Date: 5/17/2018
#
# Respondent is assessed an administrative penalty in the amount of $575. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# NGUYEN, TUAN A
# City: AUSTIN
# County: TRAVIS
# Zip Code: 78723
#
# NGUYEN, TUAN VAN
# City: ARLINGTON
# County: TARRANT
# Zip Code: 76011
#
#
# License #: 681274
#
# Complaint # COS20140018343 Date: 5/9/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,000. Respondent failed to clean and disinfect all wax pots; Respondent failed to disinfect tools, implements, and supplies with a hospital-grade EPA-registered disinfectant solution; Respondent failed to replace materials that contact skin, or skin products from multi-use containers, with new or clean articles for each client.
# NGUYEN, THAO B
# City: EULESS
# County: TARRANT
# Zip Code: 76039
#
#
# License #(s): 721373, 1142884
#
# Complaint # COS20180008846 Date: 5/9/2018
#
# Respondent is assessed an administrative penalty in the amount of $750. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# NGUYEN, BETH MARIA
# City: HOUSTON
# County: HARRIS
# Zip Code: 77083
#
#
# License #: 1470271
#
# Complaint # COS20180000897 Date: 4/30/2018
#
# Respondent's Cosmetology Operator license was revoked by operation of law on 03/29/16. The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary.
# NGUYEN, TRUNG N
# City: AMARILLO
# County: POTTER
# Zip Code: 79106
#
#
# License #(s): 1196244, 767015, 767014
#
# Complaint # COS20170023893 Date: 4/25/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,300. Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    try to do something
# except:
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything, you can type `pass` instead of the `print` statement.
#
# **Why doesn't the first one have a name?**

# %%
# for row in rows[1:]:
#     print(row.text)

# %%
# for row in rows[1:]:
#     cell = row.find_element_by_tag_name('td')
#     name = cell.find_element_by_tag_name('span')
#     print(name.text)

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: You can get the HTML of something by doing `.get_attribute('innerHTML')` - it might help you diagnose your issue.*
# > - *Tip: Or I guess you could just skip the one with the problem...

# %%
# for row in rows[1:]:
#     cells = row.find_elements_by_tag_name('td')   
#     info = cells[-1]
#     print(info.text)

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# - TIP: Think about the order of the elements

# %%
# for row in rows[1:]:
#     cell = row.find_element_by_tag_name('td')
#     numbers = cell.find_elements_by_tag_name('span')
#     number = numbers[-1]
#     print(number.text)

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# > *Tip: If you want to ask for the "next sibling," you can't use `find_next_sibling` in Selenium, you need to use `element.find_element_by_xpath("following-sibling::div")` to find the next div, or `element.find_element_by_xpath("following-sibling::*")` to find the next anything.

# %%
rows = driver.find_elements_by_tag_name('tr')
records = []

for row in rows[1:30]:
    record_dict = {}
    cells = row.find_elements_by_tag_name('span')
    lines = row.find_elements_by_tag_name('td')
    
    record_dict['name'] = cells[0].text
    record_dict['violation_num'] = cells[-1].text
    record_dict['license'] = cells[-3].text
    record_dict['code'] = cells[6].text
    record_dict['county'] = cells[4].text
    record_dict['city'] = cells[2].text
    record_dict['description'] = lines[-1].text
    
#     record_dict['description'] = cells[-1].text  
       
#     print(record_dict)
    records.append(record_dict)
print(records)
# Out:
# [{'name': 'NGUYEN, TOAN HUU', 'violation_num': '5/30/2018', 'license': 'COS20180004289', 'code': '78217', 'county': 'BEXAR', 'city': 'SAN ANTONIO', 'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'}, {'name': 'NGUYEN, HANH CONG', 'violation_num': '5/30/2018', 'license': 'COS20180006594', 'code': '79934', 'county': 'EL PASO', 'city': 'EL PASO', 'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.'}, {'name': 'NGUYEN, KHIEM VAN', 'violation_num': '5/17/2018', 'license': 'COS20180000257', 'code': '75604', 'county': 'GREGG', 'city': 'LONGVIEW', 'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.'}, {'name': 'NGUYEN, DIEP THI NGOC', 'violation_num': '5/17/2018', 'license': 'COS20180004915', 'code': '77014', 'county': 'HARRIS', 'city': 'HOUSTON', 'description': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client.'}, {'name': 'NGUYEN, LAN T-THUY', 'violation_num': '5/17/2018', 'license': 'COS20180009255', 'code': '78255', 'county': 'BEXAR', 'city': 'SAN ANTONIO', 'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'}, {'name': 'NGUYEN, TUAN A', 'violation_num': '5/9/2018', 'license': 'COS20140018343', 'code': '78723', 'county': 'TRAVIS', 'city': 'AUSTIN', 'description': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to disinfect tools, implements, and supplies with a hospital-grade EPA-registered disinfectant solution; Respondent failed to replace materials that contact skin, or skin products from multi-use containers, with new or clean articles for each client.'}, {'name': 'NGUYEN, THAO B', 'violation_num': '5/9/2018', 'license': 'COS20180008846', 'code': '76039', 'county': 'TARRANT', 'city': 'EULESS', 'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'}, {'name': 'NGUYEN, BETH MARIA', 'violation_num': '4/30/2018', 'license': 'COS20180000897', 'code': '77083', 'county': 'HARRIS', 'city': 'HOUSTON', 'description': "The Respondent's license was revoked upon Respondent's imprisonment in a penitentiary."}, {'name': 'NGUYEN, TRUNG N', 'violation_num': '4/25/2018', 'license': 'COS20170023893', 'code': '79106', 'county': 'POTTER', 'city': 'AMARILLO', 'description': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'}, {'name': 'NGUYEN, NGAT THI', 'violation_num': '4/25/2018', 'license': 'COS20180004076', 'code': '75686', 'county': 'CAMP', 'city': 'PITTSBURG', 'description': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution.'}, {'name': 'NGUYEN, KELLY PHUONG N', 'violation_num': '4/25/2018', 'license': 'COS20180004498', 'code': '78413', 'county': 'NUECES', 'city': 'CORPUS CHRISTI', 'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'}, {'name': 'NGUYEN, CHAU THI', 'violation_num': '4/25/2018', 'license': 'COS20180008220', 'code': '77901', 'county': 'VICTORIA', 'city': 'VICTORIA', 'description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'}, {'name': 'NGUYEN, XUAN T', 'violation_num': '4/16/2018', 'license': 'COS20170009055', 'code': '77396', 'county': 'H ...

# %% [markdown]
# ### Save that to a CSV
#
# - Tip: You'll want to use pandas here

# %%
import pandas as pd

# %%
df = pd.DataFrame(records)
df.head()
# Out:
#           city   code   county  \
# 0  SAN ANTONIO  78217    BEXAR
# 1      EL PASO  79934  EL PASO
# 2     LONGVIEW  75604    GREGG
# 3      HOUSTON  77014   HARRIS
# 4  SAN ANTONIO  78255    BEXAR
#
#                                          description         license  \
# 0  Respondent failed to clean and sanitize whirlp...  COS20180004289
# 1  Respondent failed to clean and sanitize whirlp...  COS20180006594
# 2  Respondent failed to follow whirlpool foot spa...  COS20180000257
# 3  Respondent failed to disinfect tools, implemen...  COS20180004915
# 4  Respondent failed to clean, disinfect, and ste...  COS20180009255
#
#                     name violation_num
# 0       NGUYEN, TOAN HUU     5/30/2018
# 1      NGUYEN, HANH CONG     5/30/2018
# 2      NGUYEN, KHIEM VAN     5/17/2018
# 3  NGUYEN, DIEP THI NGOC     5/17/2018
# 4     NGUYEN, LAN T-THUY     5/17/2018

# %%
df = df[['name', 'description', 'violation_num', 'code', 'county', 'city']]

# %%
df.shape
# Out:
# (29, 6)

# %%
df.to_csv("scraping_texas_results_30.csv", index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
pd.read_csv("scraping_texas_results_30.csv")
# Out:
#                       name                                        description  \
# 0         NGUYEN, TOAN HUU  Respondent failed to clean and sanitize whirlp...
# 1        NGUYEN, HANH CONG  Respondent failed to clean and sanitize whirlp...
# 2        NGUYEN, KHIEM VAN  Respondent failed to follow whirlpool foot spa...
# 3    NGUYEN, DIEP THI NGOC  Respondent failed to disinfect tools, implemen...
# 4       NGUYEN, LAN T-THUY  Respondent failed to clean, disinfect, and ste...
# 5           NGUYEN, TUAN A  Respondent failed to clean and disinfect all w...
# 6           NGUYEN, THAO B  Respondent failed to clean and sanitize whirlp...
# 7       NGUYEN, BETH MARIA  The Respondent's license was revoked upon Resp...
# 8          NGUYEN, TRUNG N  Respondent failed to clean, disinfect, and ste...
# 9         NGUYEN, NGAT THI  Respondent failed to follow whirlpool foot spa...
# 10  NGUYEN, KELLY PHUONG N  Respondent failed to clean and sanitize whirlp...
# 11        NGUYEN, CHAU THI  Respondent failed to clean and sanitize whirlp...
# 12          NGUYEN, XUAN T  Respondent failed to clean and sanitize whirlp...
# 13         NGUYEN, THANH C  Respondent failed to disinfect tools, implemen...
# 14             NGUYEN, HAI  Respondent failed to clean, disinfect, and ste...
# 15      NGUYEN, JENNIFER T  Respondent failed to clean and sanitize whirlp...
# 16        NGUYEN, TONY VAN  Respondent failed to clean and sanitize whirlp...
# 17  NGUYEN, HANH THAO TRAN  Respondent failed to clean, disinfect, and ste...
# 18   NGUYEN, QUYEN THI MAI  Respondent failed to follow whirlpool foot spa...
# 19        NGUYEN, OANH THI  Respondent failed to follow whirlpool foot spa...
# 20         NGUYEN, THU NHU  Respondent failed to disinfect tools, implemen...
# 21       NGUYEN, PHUNG THI  Respondent failed to clean and sanitize whirlp...
# 22            NGUYEN, TUAN  Respondent failed to clean and sanitize whirlp...
# 23        NGUYEN, PHUOC BA  Respondent failed to clean and sanitize whirlp...
# 24        NGUYEN, THAI VAN  Respondent failed to clean, disinfect, and ste...
# 25           NGUYEN, JIMMY  Respondent leased space in a salon to an indiv...
# 26         NGUYEN, QUI VAN  Respondent failed to possess an autoclave, dry...
# 27   NGUYEN, KIM LIEN TRAN  Respondent failed to disinfect tools, implemen...
# 28       NGUYEN, THUY HONG  Respondent failed to comply with an order prev...
#
#    violation_num   code     county            city
# 0      5/30/2018  78217      BEXAR     SAN ANTONIO
# 1      5/30/2018  79934    EL PASO         EL PASO
# 2      5/17/2018  75604      GREGG        LONGVIEW
# 3      5/17/2018  77014     HARRIS         HOUSTON
# 4      5/17/2018  78255      BEXAR     SAN ANTONIO
# 5       5/9/2018  78723     TRAVIS          AUSTIN
# 6       5/9/2018  76039    TARRANT          EULESS
# 7      4/30/2018  77083     HARRIS         HOUSTON
# 8      4/25/2018  79106     POTTER        AMARILLO
# 9      4/25/2018  75686       CAMP       PITTSBURG
# 10     4/25/2018  78413     NUECES  CORPUS CHRISTI
# 11     4/25/2018  77901   VICTORIA        VICTORIA
# 12     4/16/2018  77396     HARRIS         HOUSTON
# 13     4/16/2018  77072     HARRIS         HOUSTON
# 14      4/9/2018  75071     COLLIN        MCKINNEY
# 15      4/9/2018  79912    EL PASO         EL PASO
# 16      4/9/2018  78230      BEXAR     SAN ANTONIO
# 17      4/9/2018  78413     NUECES  CORPUS CHRISTI
# 18      4/9/2018  76502       BELL          TEMPLE
# 19      4/9/2018  77351       POLK      LIVINGSTON
# 20      4/9/2018  75212     DALLAS          DALLAS
# 21      4/9/2018  77979    CALHOUN     PORT LAVACA
# 22      4/9/2018  78414     NUECES  CORPUS CHRISTI
# 23      4/4/2018  78250      BEXAR     SAN ANTONIO
# 24     3/26/2018  75040     DALLAS         GARLAND
# 25     3/26/2018  76541       BELL         KILLEEN
# 26     3/26/2018  76002    TARRANT       ARLINGTON
# 27     3/22/2018  77407  FORT BEND        RICHMOND
# 28     3/14/2018  75054     DALLAS   GRAND PRAIRIE
