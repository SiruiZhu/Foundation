# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm), thank goodness we can search for these things.

# %% [markdown]
# ## Setup: Import what you'll need to search and scrape and Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ## Starting from `https://arlweb.msha.gov/drs/drshome.htm`, search for every operator with 'dirt' in their name, including abandoned mines.
#
# > - *Tip: If you can't make an element work using name, class or ID, try to use the XPath*

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://arlweb.msha.gov/drs/drshome.htm')

# %%
text_input = driver.find_element_by_name('OperSearch')

# %%
driver.execute_script("arguments[0].scrollIntoView(true)", text_input)

# %%
text_input.send_keys('dirt')

# %%
button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[7]/td[3]/input[1]')
button.click()

# %% [markdown]
# ## Scrape the results page, saving it as `dirt-operators.csv`
#
# > - *Tip: Think about what each row in your dataset will be, and start by looping through that*
# > - *Tip: Printing is cool and good! Print everything! Move it into a dictionary later.*
# > - *Tip: If you don't want a row, think about what's in the row that makes it different. You can use an `if` statement or list slicing to skip the ones you aren't interested in.*
# > - *Tip: Make sure your dictionary and your loop variable have DIFFERENT NAMES*
# > - *Tip: After you've made your dictionary (and printed it, of course), you'll want to add it to your list of rows*
# > - *Tip: Be sure to import pandas to convert it to a dataframe*
# > - *Tip: Make sure you don't include the index when saving your dataframe*

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be a row of your data. What is the index of the first row element that is actually a result?
#
# `.text` will help you here.

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# You can use list slicing or an `if` statement to skip the non-data row(s).

# %%
rows = driver.find_elements_by_tag_name('tr')
for row in rows[7:-1]:
    cells = row.find_elements_by_tag_name('td')
    mine_name = cells[2].text
    print(mine_name)
# Out:
# Newberg Rock & Dirt
# Bender Sand & Dirt
# Dirt Company
# Dirt Doctor Inc
# Dirt Work Specialists LLC
# Dirt Works
# Holley Dirt Company, Inc
# Krueger Brothers Gravel & Dirt
# M R Dirt
# M.R. Dirt Inc.
# P B Dirt Movers, Inc
# P B Dirt Movers, Inc.
# PB Dirt Movers
# Prescott Dirt, LLC
# R D Blankenship Dirt Work LLC
# Sand & Dirt, Inc
# SIMPSON DIRTWORX LLC
# SIMPSON DIRTWORX LLC
# Spry's Dirt & Gravel, Inc.
# Vogt Dirt Service

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
rows = driver.find_elements_by_tag_name('tr')
for row in rows[7:-1]:
    cells = row.find_elements_by_tag_name('td')
    ID = cells[0].text
    print(ID)
# Out:
# 3503598
# 1401575
# 5001797
# 2103723
# 2103914
# 4104757
# 0801306
# 3901432
# 3609624
# 3609931
# 1519799
# 4407379
# 4407296
# 0203332
# 2901986
# 0801417
# 4300768
# 4300776
# 2302283
# 2103518

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.

# %%
results = []
rows = driver.find_elements_by_tag_name('tr')
for row in rows[7:-1]:
    cells = row.find_elements_by_tag_name('td')
    result = {}
    
    result['ID'] = cells[0].text
    result['state'] = cells[1].text
    result['operator'] = cells[2].text
    result['mine_name'] = cells[3].text
    result['Type'] = cells[4].text
    result['Coalmetal'] = cells[5].text
    result['status'] = cells[6].text
    result['commodity'] = cells[7].text   
#     print("Dictionary looks like", result)
    
    results.append(result)
print(results)
# Out:
# [{'ID': '3503598', 'state': 'OR ', 'operator': 'Newberg Rock & Dirt  ', 'mine_name': 'Newberg Rock & Dirt', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Active ', 'commodity': 'Crushed, Broken Stone NEC '}, {'ID': '1401575', 'state': 'KS ', 'operator': 'Bender Sand & Dirt  ', 'mine_name': 'BENDER SAND & DIRT', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '5001797', 'state': 'AK ', 'operator': 'Dirt Company  ', 'mine_name': 'Bush Pilot', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '2103723', 'state': 'MN ', 'operator': 'Dirt Doctor Inc  ', 'mine_name': 'Rock Lake Plant', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '2103914', 'state': 'MN ', 'operator': 'Dirt Work Specialists LLC  ', 'mine_name': 'Astec Plant', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '4104757', 'state': 'TX ', 'operator': 'Dirt Works  ', 'mine_name': 'Portable #1', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '0801306', 'state': 'FL ', 'operator': 'Holley Dirt Company, Inc  ', 'mine_name': 'River Road Pit', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Active ', 'commodity': 'Sand, Common '}, {'ID': '3901432', 'state': 'SD ', 'operator': 'Krueger Brothers Gravel & Dirt  ', 'mine_name': 'PORTABLE SCREENER', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '3609624', 'state': 'PA ', 'operator': 'M R Dirt  ', 'mine_name': 'Forbes Pit', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Temporarily Idled ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '3609931', 'state': 'PA ', 'operator': 'M.R. Dirt Inc.  ', 'mine_name': 'Camptown Quarry', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Dimension Stone NEC '}, {'ID': '1519799', 'state': 'KY ', 'operator': 'P B Dirt Movers, Inc  ', 'mine_name': 'Fedscreek Surface', 'Type': 'Surface', 'Coalmetal': 'C ', 'status': 'Active ', 'commodity': 'Coal (Bituminous) '}, {'ID': '4407379', 'state': 'VA ', 'operator': 'P B Dirt Movers, Inc.  ', 'mine_name': 'No. 3', 'Type': 'Surface', 'Coalmetal': 'C ', 'status': 'New Mine ', 'commodity': ' '}, {'ID': '4407296', 'state': 'VA ', 'operator': 'PB Dirt Movers  ', 'mine_name': 'Mine No. 6', 'Type': 'Underground', 'Coalmetal': 'C ', 'status': 'Temporarily Idled ', 'commodity': 'Coal (Bituminous) '}, {'ID': '0203332', 'state': 'AZ ', 'operator': 'Prescott Dirt, LLC  ', 'mine_name': 'Sandretto Drive', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '2901986', 'state': 'NM ', 'operator': 'R D Blankenship Dirt Work LLC  ', 'mine_name': 'R D BLANKENSHIP DIRT WORK', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Active ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '0801417', 'state': 'FL ', 'operator': 'Sand & Dirt, Inc  ', 'mine_name': 'Molino Pit', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Active ', 'commodity': 'Sand, Common '}, {'ID': '4300768', 'state': 'VT ', 'operator': 'SIMPSON DIRTWORX LLC  ', 'mine_name': 'Pettibone Jaw Crusher', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '4300776', 'state': 'VT ', 'operator': 'SIMPSON DIRTWORX LLC  ', 'mine_name': 'Chieftan 1400', 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '2302283', 'state': 'MO ', 'operator': "Spry's Dirt & Gravel, Inc.  ", 'mine_name': "Mike's Money Pit", 'Type': 'Surface', 'Coalmetal': 'M ', 'status': 'Intermittent ', 'commodity': 'Construction Sand and Gravel '}, {'ID': '2103518', 'state': 'MN ', 'operator ...

# %%
##way 2
# results = []
# rows = driver.find_elements_by_tag_name('tr')
# for row in rows[7:-1]:
#     cells = row.find_elements_by_tag_name('td')
#     result = {}

#     elements = row.find_elements_by_tag_name('font')
    
#     result['ID'] = elements[0].text
#     result['state'] = elements[1].text
#     result['operator'] = elements[2].text
#     result['mine_name'] = elements[3].text
#     result['Type'] = elements[4].text
#     result['Coalmetal'] = elements[5].text
#     result['status'] = elements[6].text
#     result['commodity'] = elements[7].text   

    
#     results.append(result)
# print(results)

# %% [markdown]
# ### Save that to a CSV named `dirt-operators.csv`

# %%
import pandas as pd

# %%
df = pd.DataFrame(results)
df
# Out:
#    Coalmetal       ID         Type                      commodity  \
# 0         M   3503598      Surface     Crushed, Broken Stone NEC
# 1         M   1401575      Surface  Construction Sand and Gravel
# 2         M   5001797      Surface  Construction Sand and Gravel
# 3         M   2103723      Surface  Construction Sand and Gravel
# 4         M   2103914      Surface  Construction Sand and Gravel
# 5         M   4104757      Surface  Construction Sand and Gravel
# 6         M   0801306      Surface                  Sand, Common
# 7         M   3901432      Surface  Construction Sand and Gravel
# 8         M   3609624      Surface  Construction Sand and Gravel
# 9         M   3609931      Surface           Dimension Stone NEC
# 10        C   1519799      Surface             Coal (Bituminous)
# 11        C   4407379      Surface
# 12        C   4407296  Underground             Coal (Bituminous)
# 13        M   0203332      Surface  Construction Sand and Gravel
# 14        M   2901986      Surface  Construction Sand and Gravel
# 15        M   0801417      Surface                  Sand, Common
# 16        M   4300768      Surface  Construction Sand and Gravel
# 17        M   4300776      Surface  Construction Sand and Gravel
# 18        M   2302283      Surface  Construction Sand and Gravel
# 19        M   2103518      Surface  Construction Sand and Gravel
#
#                     mine_name                          operator state  \
# 0         Newberg Rock & Dirt             Newberg Rock & Dirt     OR
# 1          BENDER SAND & DIRT              Bender Sand & Dirt     KS
# 2                  Bush Pilot                    Dirt Company     AK
# 3             Rock Lake Plant                 Dirt Doctor Inc     MN
# 4                 Astec Plant       Dirt Work Specialists LLC     MN
# 5                 Portable #1                      Dirt Works     TX
# 6              River Road Pit        Holley Dirt Company, Inc     FL
# 7           PORTABLE SCREENER  Krueger Brothers Gravel & Dirt     SD
# 8                  Forbes Pit                        M R Dirt     PA
# 9             Camptown Quarry                  M.R. Dirt Inc.     PA
# 10          Fedscreek Surface            P B Dirt Movers, Inc     KY
# 11                      No. 3           P B Dirt Movers, Inc.     VA
# 12                 Mine No. 6                  PB Dirt Movers     VA
# 13            Sandretto Drive              Prescott Dirt, LLC     AZ
# 14  R D BLANKENSHIP DIRT WORK   R D Blankenship Dirt Work LLC     NM
# 15                 Molino Pit                Sand & Dirt, Inc     FL
# 16      Pettibone Jaw Crusher            SIMPSON DIRTWORX LLC     VT
# 17              Chieftan 1400            SIMPSON DIRTWORX LLC     VT
# 18           Mike's Money Pit      Spry's Dirt & Gravel, Inc.     MO
# 19                    Crusher               Vogt Dirt Service     MN
#
#                 status
# 0              Active
# 1        Intermittent
# 2        Intermittent
# 3        Intermittent
# 4        Intermittent
# 5        Intermittent
# 6              Active
# 7        Intermittent
# 8   Temporarily Idled
# 9        Intermittent
# 10             Active
# 11           New Mine
# 12  Temporarily Idled
# 13       Intermittent
# 14             Active
# 15             Active
# 16       Intermittent
# 17       Intermittent
# 18       Intermittent
# 19       Intermittent

# %%
df = df[['ID', 'operator', 'mine_name', 'Type', 'Coalmetal', 'status', 'commodity']]
df
# Out:
#          ID                          operator                  mine_name  \
# 0   3503598             Newberg Rock & Dirt          Newberg Rock & Dirt
# 1   1401575              Bender Sand & Dirt           BENDER SAND & DIRT
# 2   5001797                    Dirt Company                   Bush Pilot
# 3   2103723                 Dirt Doctor Inc              Rock Lake Plant
# 4   2103914       Dirt Work Specialists LLC                  Astec Plant
# 5   4104757                      Dirt Works                  Portable #1
# 6   0801306        Holley Dirt Company, Inc               River Road Pit
# 7   3901432  Krueger Brothers Gravel & Dirt            PORTABLE SCREENER
# 8   3609624                        M R Dirt                   Forbes Pit
# 9   3609931                  M.R. Dirt Inc.              Camptown Quarry
# 10  1519799            P B Dirt Movers, Inc            Fedscreek Surface
# 11  4407379           P B Dirt Movers, Inc.                        No. 3
# 12  4407296                  PB Dirt Movers                   Mine No. 6
# 13  0203332              Prescott Dirt, LLC              Sandretto Drive
# 14  2901986   R D Blankenship Dirt Work LLC    R D BLANKENSHIP DIRT WORK
# 15  0801417                Sand & Dirt, Inc                   Molino Pit
# 16  4300768            SIMPSON DIRTWORX LLC        Pettibone Jaw Crusher
# 17  4300776            SIMPSON DIRTWORX LLC                Chieftan 1400
# 18  2302283      Spry's Dirt & Gravel, Inc.             Mike's Money Pit
# 19  2103518               Vogt Dirt Service                      Crusher
#
#            Type Coalmetal              status                      commodity
# 0       Surface        M              Active      Crushed, Broken Stone NEC
# 1       Surface        M        Intermittent   Construction Sand and Gravel
# 2       Surface        M        Intermittent   Construction Sand and Gravel
# 3       Surface        M        Intermittent   Construction Sand and Gravel
# 4       Surface        M        Intermittent   Construction Sand and Gravel
# 5       Surface        M        Intermittent   Construction Sand and Gravel
# 6       Surface        M              Active                   Sand, Common
# 7       Surface        M        Intermittent   Construction Sand and Gravel
# 8       Surface        M   Temporarily Idled   Construction Sand and Gravel
# 9       Surface        M        Intermittent            Dimension Stone NEC
# 10      Surface        C              Active              Coal (Bituminous)
# 11      Surface        C            New Mine
# 12  Underground        C   Temporarily Idled              Coal (Bituminous)
# 13      Surface        M        Intermittent   Construction Sand and Gravel
# 14      Surface        M              Active   Construction Sand and Gravel
# 15      Surface        M              Active                   Sand, Common
# 16      Surface        M        Intermittent   Construction Sand and Gravel
# 17      Surface        M        Intermittent   Construction Sand and Gravel
# 18      Surface        M        Intermittent   Construction Sand and Gravel
# 19      Surface        M        Intermittent   Construction Sand and Gravel

# %% [markdown]
# ### Open the CSV file and examine the first few.
#
# Make sure you didn't save that extra weird unnamed index column.

# %%
df.to_csv("scrpping_result.csv", index=False)
